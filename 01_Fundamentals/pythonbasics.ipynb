# %%
fruits = ["apple", "banana", "apple","orange"]

fruits.reverse()

print(fruits)
# Out:
# ['orange', 'apple', 'banana', 'apple']

# %%
import numpy as np

list1=[10,20,30,40]

z=np.array(list1)

type(list1)
# Out:
# list

# %%
type(z)
# Out:
# numpy.ndarray

# %%
type(z[1])
# Out:
# numpy.int64

# %%
import random

random.seed(1)  # Setting the seed

print(np.random.randint(1, 10))
print(np.random.randint(1, 10))
print(np.random.randint(10))
np.random.randint(10,size=7)
# Out:
# 3
# 1
# 3
# array([2, 0, 1, 6, 5, 8, 7])

# %%
from skimage import io
photo=io.imread('/content/pexels-pixabay-34299.jpg')

# %%
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (3648, 5472, 3)

# %%
import matplotlib.pyplot as plt
io.imshow(photo)

# %%
io.imshow(photo[:,::2])

# %%
photo_sin=np.sin(photo)

# %%
photo_sin.shape
# Out:
# (3648, 5472, 3)

# %%
z=np.array([10,20,15,18,22])
z>18
# Out:
# array([False,  True, False, False,  True])

# %%
z[z>18]
# Out:
# array([20, 22])

# %%
photo_ma=np.where(photo>0,0,255)
io.imshow(photo_ma)

# %%
arr = np.random.rand(3, 2)
print(arr)
# Out:
# [[0.48456039 0.41247588]
#  [0.35715208 0.25494339]
#  [0.91814208 0.11817687]]

# %%
arr = np.random.randint(10)
print(arr)
# Out:
# 3

# %%
arr = np.array([1, 2, 3, 4, 5])
percentile_50 = np.percentile(arr, 50)
print(percentile_50)  # Output: 3.0
# Out:
# 3.0

# %%
arr = np.array([10, 90, 80, 45, 55])
percentile_50 = np.percentile(arr, 50)
print(percentile_50)  # Output: 3.0
# Out:
# 55.0

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
split_arr = np.split(arr, 3)
print(split_arr)  # Output: [array([1, 2]), array([3, 4]), array([5, 6])]
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
split_arr = np.split(arr, 2)
print(split_arr)  # Output: [array([1, 2]), array([3, 4]), array([5, 6])]
# Out:
# [array([1, 2, 3]), array([4, 5, 6])]

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
split_arr = np.split(arr, 1)
print(split_arr)  # Output: [array([1, 2]), array([3, 4]), array([5, 6])]
# Out:
# [array([1, 2, 3, 4, 5, 6])]
