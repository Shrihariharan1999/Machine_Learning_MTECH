# %%
# !pip install -q datascience
# !pip install -q ydata-profiling

# %%
# !pip install -q --upgrade ydata-profiling

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from ydata_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                             # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
data = pd.read_csv('/content/car_sales.csv', encoding='cp1252')
print('Data Shape:', data.shape)
data.sample(10)
# Out:
# Data Shape: (9576, 10)
#                 car      price       body  mileage  engV engType registration  \
# 3133     Volkswagen  21500.000  crossover      178   3.0  Diesel          yes
# 4903            VAZ   3450.000      hatch      128   1.6     Gas          yes
# 7816      SsangYong  20410.845  crossover        0   2.0  Diesel          yes
# 6695     Volkswagen   3300.000      vagon      193   1.9  Diesel           no
# 5818            BMW   9500.000      sedan      315   2.5  Diesel          yes
# 6022           Ford   1400.000      sedan        1   2.0     Gas          yes
# 7841  Mercedes-Benz  58500.000  crossover      128   3.0  Diesel          yes
# 3446          Mazda  11300.000  crossover       56   2.3  Petrol          yes
# 7224     Volkswagen  13500.000      sedan      104   1.8  Petrol          yes
# 3081           Audi   2100.000      vagon      275   2.5  Diesel           no
#
#       year      model  drive
# 3133  2008    Touareg   full
# 4903  2007       2114  front
# 7816  2014    Korando  front
# 6695  2003  Passat B5  front
# 5818  2001        525   rear
# 6022  1990    Scorpio   rear
# 7841  2013     ML 350   full
# 3446  2008       CX-7   full
# 7224  2010  Passat B6  front
# 3081  1998         A4   full

# %%
data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
data.drop(['engV'], axis=1, inplace=True)

# %%
data.loc[data.price == 0]
# Out:
#                 car  price       body  mileage engType registration  year  \
# 20       Land Rover    0.0  crossover        0  Diesel          yes  2016
# 53    Mercedes-Benz    0.0  crossover        0  Diesel          yes  2016
# 70    Mercedes-Benz    0.0  crossover        0  Diesel          yes  2016
# 71           Toyota    0.0  crossover        0  Diesel          yes  2016
# 90          Porsche    0.0      sedan       22  Petrol          yes  2014
# ...             ...    ...        ...      ...     ...          ...   ...
# 9019         Toyota    0.0      hatch       76  Petrol          yes  2007
# 9025  Mercedes-Benz    0.0  crossover        1  Petrol          yes  2016
# 9036           Ford    0.0      other        1  Petrol          yes  2014
# 9442        Renault    0.0      vagon      137  Diesel          yes  2008
# 9470       Chrysler    0.0      vagon      198  Petrol          yes  2001
#
#                  model  drive
# 20         Range Rover   full
# 53           GLE-Class   full
# 70           GLE-Class   full
# 71    Land Cruiser 200   full
# 90            Panamera   full
# ...                ...    ...
# 9019              Aygo  front
# 9025         GLE-Class   full
# 9036           Mustang   rear
# 9442      Kangoo ïàññ.  front
# 9470        PT Cruiser  front
#
# [267 rows x 9 columns]

# %%
data.drop(data[data.price == 0].index, inplace=True)
data.head()
# Out:
#              car    price       body  mileage engType registration  year  \
# 0           Ford  15500.0  crossover       68     Gas          yes  2010
# 1  Mercedes-Benz  20500.0      sedan      173     Gas          yes  2011
# 2  Mercedes-Benz  35000.0      other      135  Petrol          yes  2008
# 3  Mercedes-Benz  17800.0        van      162  Diesel          yes  2012
# 4  Mercedes-Benz  33000.0      vagon       91   Other          yes  2013
#
#      model  drive
# 0     Kuga   full
# 1  E-Class   rear
# 2   CL 550   rear
# 3    B 180  front
# 4  E-Class    NaN

# %%
popular_brands = data.car.value_counts().head(10)
popular_brands
# Out:
# car
# Volkswagen       908
# Mercedes-Benz    852
# BMW              669
# Toyota           523
# VAZ              480
# Renault          456
# Audi             442
# Opel             395
# Nissan           366
# Skoda            363
# Name: count, dtype: int64

# %%
# !pip uninstall seaborn

# %%
import seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,9))
plt.title('Most Popular Car Brand')
plt.xlabel('Count')
plt.ylabel('Car Brands')
sns.barplot(x = popular_brands.values, y = popular_brands.index);
