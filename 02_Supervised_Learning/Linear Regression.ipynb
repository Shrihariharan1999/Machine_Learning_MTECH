# %%
#import packages
from pandas import read_csv
from sklearn.model_selection import train_test_split

# %%
#loading dataset
def load_dataset(fname):
    data=read_csv(fname)
    dataset=data.values
    X=dataset[:,:-1]
    y=dataset[:,-1]
    return X,y

# %%
#Train Test split
X,y=load_dataset('E:\\sweetlin-official\\Win 2022 -23\\Data Analytics\\Lab\dataset\\BostonHousing.csv')
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=1)
print('Train',X_train.shape,y_train.shape)
print('Test',X_test.shape,y_test.shape)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-776355868.py:2: SyntaxWarning: invalid escape sequence '\d'
#   X,y=load_dataset('E:\\sweetlin-official\\Win 2022 -23\\Data Analytics\\Lab\dataset\\BostonHousing.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-776355868.py in <cell line: 0>()
#       1 #Train Test split
# ----> 2 X,y=load_dataset('E:\\sweetlin-official\\Win 2022 -23\\Data Analytics\\Lab\dataset\\BostonHousing.csv')
#       3 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=1)
#       4 print('Train',X_train.shape,y_train.shape)
#       5 print('Test',X_test.shape,y_test.shape)
#
# /tmp/ipython-input-524849674.py in load_dataset(fname)
#       1 #loading dataset
#       2 def load_dataset(fname):
# ----> 3     data=read_csv(fname)
#       4     dataset=data.values
#       5     X=dataset[:,:-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\sweetlin-official\\Win 2022 -23\\Data Analytics\\Lab\\dataset\\BostonHousing.csv'

# %%
from sklearn.linear_model import LinearRegression

# %%
#model building
model=LinearRegression()
model.fit(X_train,y_train)

# %%
#model score
rsq=model.score(X_train,y_train)
print("R-square value",rsq)

# %%
#model parameters
print('w0',model.intercept_)
print('w1',model.coef_)

# %%
#prediction
ypred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import math

# %%
#Evaluate the model
MSE=mean_squared_error(y_test,ypred)
RMSE=math.sqrt(MSE)
print('Mean squared Error',MSE)
print('Root Mean squared Error',RMSE)

# %%
#Evaluate the model
MAE=mean_absolute_error(y_test,ypred)
print('Mean Absolute Error',MAE)
