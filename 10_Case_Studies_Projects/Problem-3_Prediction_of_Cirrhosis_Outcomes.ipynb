# %%
! pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c problem-3-prediction-of-cirrhosis-outcomes
# Out:
# problem-3-prediction-of-cirrhosis-outcomes.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip /content/problem-3-prediction-of-cirrhosis-outcomes.zip
# Out:
# Archive:  /content/problem-3-prediction-of-cirrhosis-outcomes.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import pandas as pd
import numpy as np

# %%
tr=pd.read_csv('/content/train.csv')

# %%
te=pd.read_csv("/content/test.csv")

# %%
tr.head()
# Out:
#    id  N_Days             Drug      Age Sex Ascites Hepatomegaly Spiders  \
# 0   0  1087.0              NaN  19724.0   F     NaN          NaN     NaN
# 1   1  1443.0              NaN  14975.0   F     NaN          NaN     NaN
# 2   2  2855.0              NaN  19724.0   M     NaN          NaN     NaN
# 3   3  1654.0              NaN  21550.0   F     NaN          NaN     NaN
# 4   4   221.0  D-penicillamine  28018.0   F       Y            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# 0     N        1.8          NaN     3.82     NaN       NaN    NaN
# 1     N        1.0          NaN     3.64     NaN       NaN    NaN
# 2     N        1.2          NaN     3.40     NaN       NaN    NaN
# 3     N        1.8          NaN     3.14     NaN       NaN    NaN
# 4     Y       21.6        261.0     2.43   155.0    1768.0  151.9
#
#    Tryglicerides  Platelets  Prothrombin  Stage Status
# 0            NaN      183.0         10.3    3.0      D
# ...

# %%
te.head()
# Out:
#       id  N_Days             Drug      Age Sex Ascites Hepatomegaly Spiders  \
# 0  15000    41.0              NaN  16071.0   F     NaN          NaN     NaN
# 1  15001  2580.0  D-penicillamine  15601.0   F       N            N       N
# 2  15002  3992.0  D-penicillamine  20440.0   F       N            N       N
# 3  15003  3021.0              NaN  15177.0   F     NaN          NaN     NaN
# 4  15004  1170.0              NaN  22646.0   F     NaN          NaN     NaN
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# 0     N        3.3          NaN     3.75     NaN       NaN    NaN
# 1     N        0.9        223.0     4.38    20.0     657.0  57.35
# 2     N        0.6        273.0     3.20    22.0     423.0  49.60
# 3     N        0.9          NaN     3.40     NaN       NaN    NaN
# 4     N        0.6          NaN     3.78     NaN       NaN    NaN
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0            NaN      160.0         11.1    4.0
# ...

# %%
tr.describe()
# Out:
#                  id        N_Days            Age     Bilirubin  Cholesterol  \
# count  15000.000000  15000.000000   15000.000000  15000.000000  6565.000000
# mean    7499.500000   1957.803733   19355.880067      1.837787   324.009901
# std     4330.271354   1369.985666    3888.952325      2.710927   172.808687
# min        0.000000     28.000000     820.000000      0.300000    53.000000
# 25%     3749.750000   1092.000000   16728.000000      0.600000   239.000000
# 50%     7499.500000   1769.000000   19724.000000      0.900000   280.000000
# 75%    11249.250000   2598.000000   22347.000000      1.800000   360.000000
# max    14999.000000  25772.000000  189992.000000     28.000000  2176.000000
#
#             Albumin       Copper      Alk_Phos         SGOT  Tryglicerides  \
# count  15000.000000  8295.000000   8390.000000  8390.000000    6507.000000
# mean       3.526019    73.971911   1655.571692   104.676073     109.451514
# ...

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15000 non-null  int64
#  1   N_Days         15000 non-null  float64
#  2   Drug           8402 non-null   object
#  3   Age            15000 non-null  float64
#  4   Sex            15000 non-null  object
#  5   Ascites        8403 non-null   object
#  6   Hepatomegaly   8393 non-null   object
#  7   Spiders        8392 non-null   object
#  8   Edema          15000 non-null  object
#  9   Bilirubin      15000 non-null  float64
#  10  Cholesterol    6565 non-null   float64
#  11  Albumin        15000 non-null  float64
#  12  Copper         8295 non-null   float64
#  13  Alk_Phos       8390 non-null   float64
#  14  SGOT           8390 non-null   float64
#  15  Tryglicerides  6507 non-null   float64
#  16  Platelets      14430 non-null  float64
# ...

# %%
frames = [tr,te]
df = pd.concat(frames)

# %%
df.head()
# Out:
#    id  N_Days             Drug      Age Sex Ascites Hepatomegaly Spiders  \
# 0   0  1087.0              NaN  19724.0   F     NaN          NaN     NaN
# 1   1  1443.0              NaN  14975.0   F     NaN          NaN     NaN
# 2   2  2855.0              NaN  19724.0   M     NaN          NaN     NaN
# 3   3  1654.0              NaN  21550.0   F     NaN          NaN     NaN
# 4   4   221.0  D-penicillamine  28018.0   F       Y            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# 0     N        1.8          NaN     3.82     NaN       NaN    NaN
# 1     N        1.0          NaN     3.64     NaN       NaN    NaN
# 2     N        1.2          NaN     3.40     NaN       NaN    NaN
# 3     N        1.8          NaN     3.14     NaN       NaN    NaN
# 4     Y       21.6        261.0     2.43   155.0    1768.0  151.9
#
#    Tryglicerides  Platelets  Prothrombin  Stage Status
# 0            NaN      183.0         10.3    3.0      D
# ...

# %%
df.tail()
# Out:
#          id  N_Days     Drug      Age Sex Ascites Hepatomegaly Spiders Edema  \
# 9995  24995  2772.0  Placebo  15119.0   F       N            N       N     N
# 9996  24996  1236.0  Placebo  22156.0   F       N            Y       N     N
# 9997  24997  2812.0      NaN  18628.0   F     NaN          NaN     NaN     S
# 9998  24998   611.0  Placebo  26259.0   M       N            Y       N     N
# 9999  24999   617.0      NaN  17525.0   F     NaN          NaN     NaN     N
#
#       Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 9995        0.6        360.0     4.01    39.0    1472.0  134.00
# 9996        3.2        298.0     3.83    38.0    1212.0  151.90
# 9997        0.9          NaN     3.92     NaN       NaN     NaN
# 9998        2.3        227.0     3.04    62.0    5396.0  221.88
# 9999        1.8          NaN     3.13     NaN       NaN     NaN
#
#       Tryglicerides  Platelets  Prothrombin  Stage Status
# 9995          154.0      200.0         10.5    2.0    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             25000 non-null  int64
#  1   N_Days         25000 non-null  float64
#  2   Drug           13970 non-null  object
#  3   Age            25000 non-null  float64
#  4   Sex            25000 non-null  object
#  5   Ascites        13969 non-null  object
#  6   Hepatomegaly   13959 non-null  object
#  7   Spiders        13953 non-null  object
#  8   Edema          25000 non-null  object
#  9   Bilirubin      24999 non-null  float64
#  10  Cholesterol    10946 non-null  float64
#  11  Albumin        25000 non-null  float64
#  12  Copper         13788 non-null  float64
#  13  Alk_Phos       13951 non-null  float64
#  14  SGOT           13953 non-null  float64
#  15  Tryglicerides  10869 non-null  float64
#  16  Platelets      24057 non-null  float64
# ...

# %%
df
# Out:
#          id  N_Days             Drug      Age Sex Ascites Hepatomegaly  \
# 0         0  1087.0              NaN  19724.0   F     NaN          NaN
# 1         1  1443.0              NaN  14975.0   F     NaN          NaN
# 2         2  2855.0              NaN  19724.0   M     NaN          NaN
# 3         3  1654.0              NaN  21550.0   F     NaN          NaN
# 4         4   221.0  D-penicillamine  28018.0   F       Y            Y
# ...     ...     ...              ...      ...  ..     ...          ...
# 9995  24995  2772.0          Placebo  15119.0   F       N            N
# 9996  24996  1236.0          Placebo  22156.0   F       N            Y
# 9997  24997  2812.0              NaN  18628.0   F     NaN          NaN
# 9998  24998   611.0          Placebo  26259.0   M       N            Y
# 9999  24999   617.0              NaN  17525.0   F     NaN          NaN
#
#      Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df["Drug"].value_counts()
# Out:
# Drug
# D-penicillamine    7416
# Placebo            6553
# Drug                  1
# Name: count, dtype: int64

# %%
te["Drug"].value_counts()
# Out:
# Drug
# D-penicillamine    2923
# Placebo            2644
# Drug                  1
# Name: count, dtype: int64

# %%
df
# Out:
#          id  N_Days             Drug      Age Sex Ascites Hepatomegaly  \
# 0         0  1087.0              NaN  19724.0   F     NaN          NaN
# 1         1  1443.0              NaN  14975.0   F     NaN          NaN
# 2         2  2855.0              NaN  19724.0   M     NaN          NaN
# 3         3  1654.0              NaN  21550.0   F     NaN          NaN
# 4         4   221.0  D-penicillamine  28018.0   F       Y            Y
# ...     ...     ...              ...      ...  ..     ...          ...
# 9995  24995  2772.0          Placebo  15119.0   F       N            N
# 9996  24996  1236.0          Placebo  22156.0   F       N            Y
# 9997  24997  2812.0              NaN  18628.0   F     NaN          NaN
# 9998  24998   611.0          Placebo  26259.0   M       N            Y
# 9999  24999   617.0              NaN  17525.0   F     NaN          NaN
#
#      Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# F    23950
# M     1050
# Name: count, dtype: int64

# %%
df["Status"].value_counts()
# Out:
# Status
# C     10170
# D      4444
# CL      386
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                   0
# N_Days               0
# Drug             11030
# Age                  0
# Sex                  0
# Ascites          11031
# Hepatomegaly     11041
# Spiders          11047
# Edema                0
# Bilirubin            1
# Cholesterol      14054
# Albumin              0
# Copper           11212
# Alk_Phos         11049
# SGOT             11047
# Tryglicerides    14131
# Platelets          943
# Prothrombin         34
# Stage                0
# Status           10000
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id               0
# N_Days           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# Status           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6253 entries, 4 to 14994
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             6253 non-null   int64
#  1   N_Days         6253 non-null   float64
#  2   Drug           6253 non-null   object
#  3   Age            6253 non-null   float64
#  4   Sex            6253 non-null   object
#  5   Ascites        6253 non-null   object
#  6   Hepatomegaly   6253 non-null   object
#  7   Spiders        6253 non-null   object
#  8   Edema          6253 non-null   object
#  9   Bilirubin      6253 non-null   float64
#  10  Cholesterol    6253 non-null   float64
#  11  Albumin        6253 non-null   float64
#  12  Copper         6253 non-null   float64
#  13  Alk_Phos       6253 non-null   float64
#  14  SGOT           6253 non-null   float64
#  15  Tryglicerides  6253 non-null   float64
#  16  Platelets      6253 non-null   float64
# ...

# %%
tr.shape
# Out:
# (15000, 20)

# %%
te.shape
# Out:
# (10000, 19)

# %%
tr.shape
# Out:
# (15000, 20)

# %%
te.shape
# Out:
# (10000, 19)

# %%
tr
# Out:
#           id  N_Days             Drug      Age Sex Ascites Hepatomegaly  \
# 0          0  1087.0              NaN  19724.0   F     NaN          NaN
# 1          1  1443.0              NaN  14975.0   F     NaN          NaN
# 2          2  2855.0              NaN  19724.0   M     NaN          NaN
# 3          3  1654.0              NaN  21550.0   F     NaN          NaN
# 4          4   221.0  D-penicillamine  28018.0   F       Y            Y
# ...      ...     ...              ...      ...  ..     ...          ...
# 14995  14995  1097.0              NaN  22646.0   F     NaN          NaN
# 14996  14996  1000.0  D-penicillamine  24622.0   F       N            Y
# 14997  14997  4214.0              NaN  17897.0   F     NaN          NaN
# 14998  14998  1654.0              NaN  16071.0   F     NaN          NaN
# 14999  14999   786.0  D-penicillamine  19884.0   F       N            N
#
#       Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  \
# ...

# %%
x_train=tr.drop(columns=["id","Status"])

# %%
y_train=tr["Status"]

# %%
x_train
# Out:
#        N_Days             Drug      Age Sex Ascites Hepatomegaly Spiders  \
# 0      1087.0              NaN  19724.0   F     NaN          NaN     NaN
# 1      1443.0              NaN  14975.0   F     NaN          NaN     NaN
# 2      2855.0              NaN  19724.0   M     NaN          NaN     NaN
# 3      1654.0              NaN  21550.0   F     NaN          NaN     NaN
# 4       221.0  D-penicillamine  28018.0   F       Y            Y       Y
# ...       ...              ...      ...  ..     ...          ...     ...
# 14995  1097.0              NaN  22646.0   F     NaN          NaN     NaN
# 14996  1000.0  D-penicillamine  24622.0   F       N            Y       N
# 14997  4214.0              NaN  17897.0   F     NaN          NaN     NaN
# 14998  1654.0              NaN  16071.0   F     NaN          NaN     NaN
# 14999   786.0  D-penicillamine  19884.0   F       N            N       Y
#
#       Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x_train["Drug"]=le.fit_transform(x_train["Drug"])
x_train["Sex"]=le.fit_transform(x_train["Sex"])
x_train["Ascites"]=le.fit_transform(x_train["Ascites"])
x_train["Hepatomegaly"]=le.fit_transform(x_train["Hepatomegaly"])
x_train["Spiders"]=le.fit_transform(x_train["Spiders"])
x_train["Edema"]=le.fit_transform(x_train["Edema"])

# %%
x_train
# Out:
#        N_Days  Drug      Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0      1087.0     2  19724.0    0        3             4        2      0
# 1      1443.0     2  14975.0    0        3             4        2      0
# 2      2855.0     2  19724.0    1        3             4        2      0
# 3      1654.0     2  21550.0    0        3             4        2      0
# 4       221.0     0  28018.0    0        2             3        1      2
# ...       ...   ...      ...  ...      ...           ...      ...    ...
# 14995  1097.0     2  22646.0    0        3             4        2      0
# 14996  1000.0     0  24622.0    0        1             3        0      0
# 14997  4214.0     2  17897.0    0        3             4        2      0
# 14998  1654.0     2  16071.0    0        3             4        2      0
# 14999   786.0     0  19884.0    0        1             2        1      0
#
#        Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
y_train
# Out:
# 0        D
# 1        C
# 2        C
# 3        D
# 4        D
#         ..
# 14995    C
# 14996    D
# 14997    D
# 14998    C
# 14999    D
# Name: Status, Length: 15000, dtype: object

# %%
y_train.value_counts()
# Out:
# Status
# C     10170
# D      4444
# CL      386
# Name: count, dtype: int64

# %%
#dummies= pd.get_dummies(y_train)
#y_train=dummies.copy()

# %%
y_train
# Out:
# 0        D
# 1        C
# 2        C
# 3        D
# 4        D
#         ..
# 14995    C
# 14996    D
# 14997    D
# 14998    C
# 14999    D
# Name: Status, Length: 15000, dtype: object

# %%
#y_train["C"]=y_train["C"].astype(int)
#y_train["D"]=y_train["D"].astype(int)
#y_train["CL"]=y_train["CL"].astype(int)

# %%
y_train=y_train.map({"C":0,"D":1,"CL":2})
y_train
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 14995    0
# 14996    1
# 14997    1
# 14998    0
# 14999    1
# Name: Status, Length: 15000, dtype: int64

# %%
#y_train_c=y_train["C"]
#y_train_d=y_train["D"]
#y_train_cl=y_train["CL"]

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression(max_iter=1000, random_state=1)
log.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-05aa55f3b06f> in <cell line: 2>()
#       1 log = LogisticRegression(max_iter=1000, random_state=1)
# ----> 2 log.fit(x_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# ...

# %%
te

# %%
te["Drug"]=le.fit_transform(te["Drug"])
te["Sex"]=le.fit_transform(te["Sex"])
te["Ascites"]=le.fit_transform(te["Ascites"])
te["Hepatomegaly"]=le.fit_transform(te["Hepatomegaly"])
te["Spiders"]=le.fit_transform(te["Spiders"])
te["Edema"]=le.fit_transform(te["Edema"])

# %%
te

# %%
te.shape

# %%
te=te.drop(columns=["id"])

# %%
te.isnull().sum()
