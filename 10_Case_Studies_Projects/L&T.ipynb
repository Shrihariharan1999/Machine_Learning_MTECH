# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
data1, labels_true = make_blobs(n_samples=200, n_features=2,centers=3, random_state=42)

# %%
pd.DataFrame(data1)
# Out:
#             0         1
# 0    6.505653  2.447003
# 1   -5.128943  9.836189
# 2   -6.891874 -7.777364
# 3   -8.327712 -8.287573
# 4   -7.468992 -6.030507
# ..        ...       ...
# 195 -6.568720 -5.404753
# 196 -0.623012  9.188864
# 197 -0.929985  9.781721
# 198  4.167947  3.062120
# 199  3.665197  2.760254
#
# [200 rows x 2 columns]

# %%
pd.DataFrame(labels_true)
# Out:
#      0
# 0    1
# 1    0
# 2    2
# 3    2
# 4    2
# ..  ..
# 195  2
# 196  0
# 197  0
# 198  1
# 199  1
#
# [200 rows x 1 columns]

# %%
plt.scatter(data[:, 0], data[:, 1])

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
pd.DataFrame(centers)
# Out:
#           0         1
# 0 -2.658821  8.957568
# 1 -6.745394 -6.851443
# 2  4.632182  2.101214

# %%
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='o', s=200,label='Centroids')
plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, color='blue', marker='o')
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
x = [5, 7, 8, 7, 2, 17]
y = [99, 86, 87, 88, 100, 86]

plt.scatter(x, y, color='red', s=100, marker='o')
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]

plt.bar(categories, values, color='green')
plt.title("Bar Plot")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
import numpy as np

data = np.random.randn(1000)

plt.hist(data,bins=20, color='red',edgecolor='black')
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %%
data = [7, 8, 5, 6, 9, 12, 7, 6, 8, 9]

plt.boxplot(data)
plt.title("Box Plot")
plt.ylabel("Values")
plt.show()

# %%
import numpy as np

data = np.random.rand(5, 5)
plt.imshow(data, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title("Heatmap")
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

fig, ax = plt.subplots(2, 2)

ax[0,0].plot(x, y)
ax[0,0].set_title("Line Plot")

ax[1,0].bar(x, y, color='orange')
ax[1,0].set_title("Bar Plot")

plt.tight_layout()
plt.show()

# %%
pd.DataFrame(data1)
# Out:
#             0         1
# 0    6.505653  2.447003
# 1   -5.128943  9.836189
# 2   -6.891874 -7.777364
# 3   -8.327712 -8.287573
# 4   -7.468992 -6.030507
# ..        ...       ...
# 195 -6.568720 -5.404753
# 196 -0.623012  9.188864
# 197 -0.929985  9.781721
# 198  4.167947  3.062120
# 199  3.665197  2.760254
#
# [200 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
a=kmeans.fit_transform(data1)

# %%
pd.DataFrame(a), pd.DataFrame(kmeans.labels_)
# Out:
# (             0          1          2
#  0    11.241666  16.188000   1.905115
#  1     2.621731  16.765738  12.454292
#  2    17.262001   0.937436  15.178609
#  3    18.152995   2.136867  16.609809
#  4    15.741034   1.094317  14.579551
#  ..         ...        ...        ...
#  195  14.885012   1.457438  13.483314
#  196   2.048907  17.169013   8.823369
#  197   1.915229  17.620475   9.483032
#  198   9.020037  14.743804   1.067172
#  199   8.854372  14.169161   1.170211
#
#  [200 rows x 3 columns],
#       0
#  0    2
#  1    0
#  2    1
#  3    1
#  4    1
#  ..  ..
#  195  1
#  196  0
#  197  0
#  198  2
#  199  2
#
#  [200 rows x 1 columns])

# %%
pd.DataFrame(data1)
# Out:
#             0         1
# 0    6.505653  2.447003
# 1   -5.128943  9.836189
# 2   -6.891874 -7.777364
# 3   -8.327712 -8.287573
# 4   -7.468992 -6.030507
# ..        ...       ...
# 195 -6.568720 -5.404753
# 196 -0.623012  9.188864
# 197 -0.929985  9.781721
# 198  4.167947  3.062120
# 199  3.665197  2.760254
#
# [200 rows x 2 columns]

# %%
kmeans.labels_
# Out:
# array([2, 0, 1, 1, 1, 1, 0, 1, 2, 1, 2, 2, 2, 2, 2, 1, 0, 1, 2, 1, 2, 2,
#        1, 0, 1, 0, 0, 1, 0, 2, 2, 2, 1, 1, 0, 0, 1, 0, 1, 0, 2, 0, 1, 2,
#        1, 2, 2, 1, 2, 0, 1, 0, 1, 0, 0, 0, 1, 2, 0, 2, 1, 0, 1, 1, 1, 1,
#        0, 0, 1, 0, 0, 1, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 1, 1, 1, 1, 0,
#        2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 2, 0, 1, 1, 0, 1, 0, 2, 1, 2, 2, 1,
#        2, 2, 0, 1, 0, 1, 1, 0, 0, 0, 1, 2, 0, 1, 1, 2, 0, 0, 2, 0, 2, 1,
#        0, 1, 1, 2, 2, 2, 0, 2, 0, 0, 1, 2, 2, 0, 2, 1, 1, 2, 0, 1, 2, 1,
#        2, 1, 1, 0, 2, 2, 0, 2, 2, 1, 0, 2, 2, 0, 1, 2, 1, 0, 2, 1, 0, 2,
#        0, 0, 0, 2, 0, 2, 1, 1, 1, 0, 2, 2, 2, 0, 0, 2, 1, 1, 0, 1, 0, 0,
#        2, 2], dtype=int32)

# %%
# Scatter plot with colors corresponding to the cluster labels
plt.scatter(data1[:, 0], data1[:, 1], c=kmeans.labels_, cmap='viridis')

# Adding legend (using unique labels)
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=plt.cm.viridis(i / 3), markersize=10)
                   for i in range(3)], labels=[f"Cluster {i}" for i in range(3)])

# Show the plot
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("KMeans Clustering")
plt.show()
